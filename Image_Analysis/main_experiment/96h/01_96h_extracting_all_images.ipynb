# %% [markdown]
# # Extracting All Images
#
# First we define the home directory and make a list mapping the index to a well identity and then a dictionary mapping well index to index

# %%
import numpy as np
import skimage.io as io
import os
import re

# needs to be changed to repository directory
home_directory = r"C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/"

letters = ["A","B","C","D","E","F","G","H"]

alphanumeric_list = []
for letter in letters:
    alphanumeric_list += [f"{letter}{i+1}" for i in range(12)]

well_to_index = {well:i for i,well in enumerate(alphanumeric_list)}

# %% [markdown]
# Now we can iterate through the folders of the experimental runs and load the stacks and save the samples to a new folder with the Experiment, Plate and Well data added. First we'll extract all images from the real experiment:

# %%
brachyury_path = home_directory + r"image_data\Processed Data\Focussed Images\96h\Brachyury"
brightfield_path = home_directory + r"image_data\Processed Data\Focussed Images\96h\Brightfield"

if not os.path.exists(brachyury_path):
   os.makedirs(brachyury_path)
   print("The new directory is created!")
if not os.path.exists(brightfield_path):
   os.makedirs(brightfield_path)
   print("The new directory is created!")

real_run_prefix = "RR"
trial_run_prefix = "TR"
brachyury_suffix = "BRA"
brightfield_suffix = "BTF"

index_to_well = {v:k for k,v in well_to_index.items()}

run = "Real_Run"
hour = "096h"

folders = next(os.walk(f'{home_directory}image_data/Raw Data/{run}/{hour}'))[1]
expression = r".*plate(?P<plate>[0-9]).*"

for folder in folders:
    if folder.startswith("FK223"):
        filenames = next(os.walk(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}/TIFs'), (None, None, []))[2]
        m = re.match(expression,folder)
        plate = m.group('plate')
        for file in filenames:
            if file.endswith("Overlay.tif"):
                stack = io.imread(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}/TIFs/{file}')
                for i, foo in enumerate(stack):
                    io.imsave(
                        f"{brightfield_path}/FK223_run_{real_run_prefix}_PLATE_{plate}_ID_{index_to_well[i]}_C_{brightfield_suffix}.tif",
                        stack[i]
                    )
            if file.endswith("BRA_focussed.tif"):
                stack = io.imread(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}/TIFs/{file}')
                for i, foo in enumerate(stack):
                    io.imsave(
                        f"{brachyury_path}/FK223_run_{real_run_prefix}_PLATE_{plate}_ID_{index_to_well[i]}_C_{brachyury_suffix}.tif",
                        stack[i]
                    )
# Out:
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:33: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_RR_PLATE_1_ID_B6_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:40: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_RR_PLATE_1_ID_B6_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:40: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_RR_PLATE_5_ID_A6_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:40: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_RR_PLATE_5_ID_B6_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:40: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_RR_PLATE_5_ID_C6_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:33: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_RR_PLATE_5_ID_A6_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:33: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_RR_PLATE_5_ID_B6_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:33: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_RR_PLATE_5_ID_C6_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:40: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_RR_PLATE_6_ID_A2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3512320587.py:33: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_RR_PLATE_6_ID_A2_C_BTF.tif is a low contrast image
#   io.imsave(

# %% [markdown]
# And now we'll extract all the images from the trial run

# %%
run = "Trial_Run"
folders = next(os.walk(f'{home_directory}image_data/Raw Data/{run}/{hour}'))[1]
for folder in folders:
    if folder.startswith("FK223"):
        print(folder)
        filenames = next(os.walk(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}'), (None, None, []))[2]
        m = re.match(expression,folder.lower())
        plate = m.group('plate')
        for file in filenames:
            if file.endswith("Overlay.tif"):
                stack = io.imread(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}/{file}')
                for i, foo in enumerate(stack):
                    io.imsave(
                        f"{brightfield_path}/FK223_run_{trial_run_prefix}_PLATE_{plate}_ID_{index_to_well[i]}_C_{brightfield_suffix}.tif",
                        stack[i]
                    )
            if file.endswith("BRA_focussed.tif"):
                stack = io.imread(f'{home_directory}image_data/Raw Data/{run}/{hour}/{folder}/{file}')
                for i, foo in enumerate(stack):
                    io.imsave(
                        f"{brachyury_path}/FK223_run_{trial_run_prefix}_PLATE_{plate}_ID_{index_to_well[i]}_C_{brachyury_suffix}.tif",
                        stack[i]
                    )
# Out:
# FK223_96h_Plate1
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_1_ID_A1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_1_ID_A2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_1_ID_A1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_1_ID_A2_C_BTF.tif is a low contrast image
#   io.imsave(
# FK223_96h_Plate2
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_A1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_A2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_A3_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_A4_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_B1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_B2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_B3_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_B10_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_C1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_C2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_C3_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_C4_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_C7_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_D1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_D2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_E1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_E2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_F1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_F2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_G1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_G2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_H1_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:20: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brachyury/FK223_run_TR_PLATE_2_ID_H2_C_BRA.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_A1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_A2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_A3_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_A4_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_B1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_B2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_B3_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_B10_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_C1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_C2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_C3_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_C4_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_C7_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_D1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_D2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_E1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_E2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_F1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_F2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_G1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_G2_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_H1_C_BTF.tif is a low contrast image
#   io.imsave(
# C:\Users\savill\AppData\Local\Temp\ipykernel_20720\3666849255.py:13: UserWarning: C:\Users\savill\OneDrive\Documents\PhD Jesse\Embryonic_organoid_prediction\Processing dataset for Paper\TLS_2D_morphostate_investigation/image_data\Processed Data\Focussed Images\96h\Brightfield/FK223_run_TR_PLATE_2_ID_H2_C_BTF.tif is a low contrast image
#   io.imsave(
